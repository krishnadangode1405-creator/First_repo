# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path='Visadataset.csv'
visa_df=pd.read_csv(path)

cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %%
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# #### prevailing_wage

# %% [markdown]
# - len
# - max
# - min
# - mean
# - median
# - 25 percentile
# - 50 percentile
# - 75 percentile

# %%
wage_data=visa_df['prevailing_wage']
len(wage_data)
# Out:
# 25480

# %%
min(wage_data)
# Out:
# 2.1367

# %%
wage_data.min()
# Out:
# 2.1367

# %%
np.min(wage_data)
# Out:
# 2.1367

# %%
wage_data=visa_df['prevailing_wage']
min(wage_data),wage_data.min(),np.min(wage_data)
# Out:
# (2.1367, 2.1367, 2.1367)

# %%
max(wage_data),wage_data.max(),np.max(wage_data)
# Out:
# (319210.27, 319210.27, 319210.27)

# %%
wage_data.mean(),np.mean(wage_data)
# Out:
# (np.float64(74455.81459209183), np.float64(74455.81459209183))

# %%
wage_data.median(),np.median(wage_data)
# Out:
# (70308.20999999999, np.float64(70308.20999999999))

# %% [markdown]
# # 12-09-2025

# %% [markdown]
# **quantile-percentile**

# %%
p_25=np.percentile(wage_data,25)
p_25
# Out:
# np.float64(34015.479999999996)

# %%
p_50=np.percentile(wage_data,50)
p_50
# Out:
# np.float64(70308.20999999999)

# %%
p_75=np.percentile(wage_data,75)
p_75
# Out:
# np.float64(107735.51250000001)

# %%
q_25=np.quantile(wage_data,0.25)
q_25
# Out:
# np.float64(34015.479999999996)

# %%
q_50=np.quantile(wage_data,0.50)
q_50
# Out:
# np.float64(70308.20999999999)

# %%
q_75=np.quantile(wage_data,0.75)
q_75
# Out:
# np.float64(107735.51250000001)

# %%
wage_data=visa_df['prevailing_wage']
wage_count=len(wage_data)
wage_min=round(wage_data.min(),2)
wage_mean=round(wage_data.mean(),2)
wage_median=round(wage_data.median(),2)
wage_25p=round(np.percentile(wage_data,25))
wage_50p=round(np.percentile(wage_data,50))
wage_75p=round(np.percentile(wage_data,75))
wage_max=round(wage_data.max(),2)
l=[wage_count,wage_min,wage_mean,wage_median,
  wage_25p,wage_50p,wage_75p,wage_max]
id=['Count','Min','Mean','Median','25p','50p','75p','Max']
pd.DataFrame(l,columns=['prevailing_wage'],index=id)
# Out:
#         prevailing_wage
# Count          25480.00
# Min                2.14
# Mean           74455.81
# Median         70308.21
# 25p            34015.00
# 50p            70308.00
# 75p           107736.00
# Max           319210.27

# %%
L=[]
for i in num:
    data=visa_df[i]
    count=len(data)
    Min=round(data.min(),2)
    mean=round(data.mean(),2)
    median=round(data.median(),2)
    p25=round(np.percentile(data,25))
    p50=round(np.percentile(data,50))
    p75=round(np.percentile(data,75))
    Max=round(wage_data.max(),2)
    l=[count,Min,mean,median,
      p25,p50,p75,Max]
    L.append(l)
    id=['Count','Min','Mean','Median','25p','50p','75p','Max']
pd.DataFrame(L,columns=id,index=num).T# Transpose
# Out:
#         no_of_employees  yr_of_estab  prevailing_wage
# Count          25480.00     25480.00         25480.00
# Min              -26.00      1800.00             2.14
# Mean            5667.04      1979.41         74455.81
# Median          2109.00      1997.00         70308.21
# 25p             1022.00      1976.00         34015.00
# 50p             2109.00      1997.00         70308.00
# 75p             3504.00      2005.00        107736.00
# Max           319210.27    319210.27        319210.27

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %% [markdown]
# **percentile concept**
#
# - 25p: 25percentage of data below 25p value
# - wage_25p: 34015.48
#     - there 25*(25480)/100= 6370applicants have salary less than 34015
# - wage_50p:  70308.21
#     - there 50*(25480)/100= 12740applicants have salary less than 70308.21
# - wage_75p:  107735.51
#     - there 75*(25480)/100= 19110applicants have salary less than 107735.51

# %%
con=visa_df['prevailing_wage']<wage_25p
len(visa_df[con]),len(visa_df)*25/100
len(visa_df[con])==len(visa_df)*25/100
# Out:
# True

# %%
len(visa_df)*25/100
# Out:
# 6370.0

# %%
con=visa_df['prevailing_wage']<wage_50p
len(visa_df[con]),len(visa_df)*50/100
len(visa_df[con])==len(visa_df)*50/100
# Out:
# True

# %%
len(visa_df)*50/100
# Out:
# 12740.0

# %%
con=visa_df['prevailing_wage']<wage_75p
len(visa_df[con]),len(visa_df)*75/100
len(visa_df[con])==len(visa_df)*75/100
# Out:
# True

# %%
len(visa_df)*75/100
# Out:
# 19110.0

# %% [markdown]
# **Emperical Rule**
#
# - u-1*sigma to u+1*sigma 68%
# - step-1: wage_data mean (u)
# - step-2: wage_data std (sigma)
# - step-3:

# %%
wage_mean
# Out:
# np.float64(74455.81)

# %%
wage_data.std()
# Out:
# 52815.94232687357

# %%
lb=74455.81-1*52815.94
ub=74455.81+1*52815.94
con1=visa_df['prevailing_wage']>lb
con2=visa_df['prevailing_wage']<ub
con=con1 & con2
len(visa_df[con])==68*25480/100
# Out:
# False

# %%
wage_data=visa_df['prevailing_wage']
U=wage_data.mean()
sigma=wage_data.std()
LB=U-1*sigma
UB=U+1*sigma
con1=visa_df['prevailing_wage']>LB
con2=visa_df['prevailing_wage']<UB
con=con1 & con2
len(visa_df[con])==68*25480/100
# Out:
# False

# %% [markdown]
# **Conclusion:** Emperical rule failed wage data does not following Noramal Distribution.

# %% [markdown]
# **Histogram**

# %%
plt.hist(wage_data,bins=40)
# Out:
# (array([2992.,  871., 1005., 1170., 1242., 1434., 1385., 1443., 1444.,
#         1445., 1457., 1335., 1268., 1217., 1088.,  978.,  807.,  645.,
#          509.,  373.,  264.,  144.,  105.,  111.,  107.,   99.,   88.,
#           79.,   65.,   64.,   58.,   53.,   33.,   33.,   29.,   19.,
#            7.,    3.,    6.,    5.]),
#  array([2.13670000e+00, 7.98234003e+03, 1.59625434e+04, 2.39427467e+04,
#         3.19229500e+04, 3.99031534e+04, 4.78833567e+04, 5.58635600e+04,
#         6.38437634e+04, 7.18239667e+04, 7.98041700e+04, 8.77843734e+04,
#         9.57645767e+04, 1.03744780e+05, 1.11724983e+05, 1.19705187e+05,
#         1.27685390e+05, 1.35665593e+05, 1.43645797e+05, 1.51626000e+05,
#         1.59606203e+05, 1.67586407e+05, 1.75566610e+05, 1.83546813e+05,
#         1.91527017e+05, 1.99507220e+05, 2.07487423e+05, 2.15467627e+05,
#         2.23447830e+05, 2.31428033e+05, 2.39408237e+05, 2.47388440e+05,
#         2.55368643e+05, 2.63348847e+05, 2.71329050e+05, 2.79309253e+05,
#         2.87289457e+05, 2.95269660e+05, 3.03249863e+05, 3.11230067e+05,
#         3.19210270e+05]),
#  <BarContainer object of 40 artists>)

# %%
inter_count,inter_vals,n=plt.hist(wage_data,bins=10)

# %%
inter_count
# Out:
# array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#          21.])

# %%
inter_vals
# Out:
# array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#        1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#        2.55368643e+05, 2.87289457e+05, 3.19210270e+05])

# %%
wage_data=visa_df['prevailing_wage']
lb=2.13670000e+00
ub=3.19229500e+04
con1=wage_data>=lb
con2=wage_data<ub
con=con1 & con2
len(visa_df[con])
# Out:
# 6038

# %%
count=[6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,21.]
values=[2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
       1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
       2.55368643e+05, 2.87289457e+05, 3.19210270e+05]
print('Class Interval\t\tFrequency')
for i in range(len(count)):
    print(f'{values[i]} - {values[i+1]}\t{count[i]}')
# Out:
# Class Interval		Frequency
# 2.1367 - 31922.95	6038.0
# 31922.95 - 63843.7634	5504.0
# 63843.7634 - 95764.5767	5681.0
# 95764.5767 - 127685.39	4551.0
# 127685.39 - 159606.203	2334.0
# 159606.203 - 191527.017	624.0
# 191527.017 - 223447.83	373.0
# 223447.83 - 255368.643	240.0
# 255368.643 - 287289.457	114.0
# 287289.457 - 319210.27	21.0

# %% [markdown]
# # 15-09-2025

# %% [markdown]
# **Outlier Analysis**

# %% [markdown]
# - We understood emperical rule fails
# - Then we ploted histogram its slightly deviated
# - So it indicates the data has outliers
# - Outliers can be show by **box plot**
#
#
#
#
#           Q1-1.5IQR   Q1   median  Q3   Q3+1.5IQR
#                        |-----:-----|
#        o      |--------|     :     |--------|    o  o
#                        |-----:-----|
#             flier                          fliers
#                             IQR

# %% [markdown]
# **Boxplot**

# %%
wage_data=visa_df['prevailing_wage']
plt.boxplot(wage_data,vert=False)
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.subplot(1,2,1).hist(wage_data)
plt.subplot(1,2,2).boxplot(wage_data,vert=False)
plt.show()

# %% [markdown]
# **Outliers Data**

# %%
# calculate 
# q1
# q2
# q3
# IQR=q3-q1
# UB=q3+1.5*IQR

# con=con1# LB=q3-1.5*IQR
# con1= wage>UB
# con2= wage<LB 
# con=con1 | con2  outliers

# %%
wage_data=visa_df['prevailing_wage']
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
IQR=q3-q1
UB=q3+1.5*IQR
LB=q1-1.5*IQR
con1= wage_data>UB
con2= wage_data<LB
con=con1 | con2
outliers_df=visa_df[con]
len(outliers_df)
# Out:
# 427

# %%
outliers_df
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 14        EZYV15           Asia              Master's                  Y
# 34        EZYV35           Asia              Master's                  N
# 130      EZYV131  South America           High School                  N
# 216      EZYV217           Asia              Master's                  Y
# 221      EZYV222  North America             Doctorate                  Y
# ...          ...            ...                   ...                ...
# 25191  EZYV25192           Asia              Master's                  N
# 25195  EZYV25196  North America              Master's                  Y
# 25468  EZYV25469           Asia            Bachelor's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25476  EZYV25477           Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 14                        Y            15756         2006
# 34                        N             1809         2010
# 130                       N             2554         2005
# 216                       N             1515         2001
# 221                       Y             2518         2010
# ...                     ...              ...          ...
# 25191                     N             4983         2005
# 25195                     N               47         2001
# 25468                     N              373         2005
# 25469                     N             2261         1997
# 25476                     N             3274         2006
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 14                   South        220081.73         Year                  Y
# 34                   South        225569.73         Year                  N
# 130                Midwest        247393.01         Year                  Y
# 216                Midwest        269321.68         Year                  N
# 221                  South        219529.62         Year                  Y
# ...                    ...              ...          ...                ...
# 25191              Midwest        280482.51         Year                  Y
# 25195                South        234308.77         Year                  N
# 25468              Midwest        272715.74         Year                  N
# 25469            Northeast        273772.47         Year                  N
# 25476            Northeast        279174.79         Year                  Y
#
#       case_status
# 14      Certified
# 34      Certified
# 130     Certified
# 216     Certified
# 221     Certified
# ...           ...
# 25191      Denied
# 25195   Certified
# 25468   Certified
# 25469   Certified
# 25476   Certified
#
# [427 rows x 12 columns]

# %%
wage_data=visa_df['prevailing_wage']
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
IQR=q3-q1
UB=q3+1.5*IQR
LB=q1-1.5*IQR
con1= wage_data<UB
con2= wage_data>LB
con=con1 & con2
non_outliers_df=visa_df[con]
len(non_outliers_df)
# Out:
# 25053

# %%
25053+427==25480
# Out:
# True

# %% [markdown]
# **Fill the Outliers**
#
# - drop the outliers
# - fill with median
# - winsorization : fill with LB and UB

# %%
outliers_df
outliers_df['prevailing_wage']
outliers_df['prevailing_wage'].values
outliers=outliers_df['prevailing_wage'].values.tolist()
l=[]
wage_data=visa_df['prevailing_wage']
wage_med=wage_data.median()
for value in wage_data:
    if value in outliers:
        l.append(wage_med)
    else:
        l.append(value)
visa_df['prevailing_wage1']=l
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status  prevailing_wage1
# 0          Denied          592.2029
# 1       Certified        83425.6500
# 2          Denied       122996.8600
# 3          Denied        83434.0300
# 4       Certified       149907.3900
# ...           ...               ...
# 25475   Certified        77092.5700
# 25476   Certified        70308.2100
# 25477   Certified       146298.8500
# 25478   Certified        86154.7700
# 25479   Certified        70876.9100
#
# [25480 rows x 13 columns]

# %%
plt.figure(figsize=(8,4))
plt.subplot(1,2,1).hist(visa_df['prevailing_wage1'])
plt.subplot(1,2,2).boxplot(visa_df['prevailing_wage1'],vert=False)
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.subplot(2,2,1).hist(visa_df['prevailing_wage1'])
plt.subplot(2,2,2).boxplot(visa_df['prevailing_wage1'],vert=False)
plt.subplot(2,2,3).hist(wage_data)
plt.subplot(2,2,4).boxplot(wage_data,vert=False)
plt.show()

# %%
wage_data=visa_df['prevailing_wage']
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
IQR=q3-q1
UB=q3+1.5*IQR
LB=q1-1.5*IQR
visa_df['prevailing_wage2']=wage_data.clip(lower=LB,upper=UB)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status  prevailing_wage1  prevailing_wage2
# 0          Denied          592.2029         592.20290
# 1       Certified        83425.6500       83425.65000
# 2          Denied       122996.8600      122996.86000
# 3          Denied        83434.0300       83434.03000
# 4       Certified       149907.3900      149907.39000
# ...           ...               ...               ...
# 25475   Certified        77092.5700       77092.57000
# 25476   Certified        70308.2100      218315.56125
# 25477   Certified       146298.8500      146298.85000
# 25478   Certified        86154.7700       86154.77000
# 25479   Certified        70876.9100       70876.91000
#
# [25480 rows x 14 columns]

# %%
plt.figure(figsize=(8,4))
plt.subplot(1,2,1).hist(visa_df['prevailing_wage2'])
plt.subplot(1,2,2).boxplot(visa_df['prevailing_wage2'],vert=False)
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.subplot(2,2,1).hist(visa_df['prevailing_wage2'])
plt.subplot(2,2,2).boxplot(visa_df['prevailing_wage2'],vert=False)
plt.subplot(2,2,3).hist(wage_data)
plt.subplot(2,2,4).boxplot(wage_data,vert=False)
plt.show()

# %% [markdown]
# # 16-09-2025

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path='Visadataset.csv'
visa_df=pd.read_csv(path)

# %%
wage_data=visa_df['prevailing_wage']
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
IQR=q3-q1
UB=q3+1.5*IQR
LB=q1-1.5*IQR
con1= wage_data>UB
con2= wage_data<LB
con=con1 | con2
outliers_df=visa_df[con]
len(outliers_df)
# Out:
# 427

# %%
outliers_df
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 14        EZYV15           Asia              Master's                  Y
# 34        EZYV35           Asia              Master's                  N
# 130      EZYV131  South America           High School                  N
# 216      EZYV217           Asia              Master's                  Y
# 221      EZYV222  North America             Doctorate                  Y
# ...          ...            ...                   ...                ...
# 25191  EZYV25192           Asia              Master's                  N
# 25195  EZYV25196  North America              Master's                  Y
# 25468  EZYV25469           Asia            Bachelor's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25476  EZYV25477           Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 14                        Y            15756         2006
# 34                        N             1809         2010
# 130                       N             2554         2005
# 216                       N             1515         2001
# 221                       Y             2518         2010
# ...                     ...              ...          ...
# 25191                     N             4983         2005
# 25195                     N               47         2001
# 25468                     N              373         2005
# 25469                     N             2261         1997
# 25476                     N             3274         2006
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 14                   South        220081.73         Year                  Y
# 34                   South        225569.73         Year                  N
# 130                Midwest        247393.01         Year                  Y
# 216                Midwest        269321.68         Year                  N
# 221                  South        219529.62         Year                  Y
# ...                    ...              ...          ...                ...
# 25191              Midwest        280482.51         Year                  Y
# 25195                South        234308.77         Year                  N
# 25468              Midwest        272715.74         Year                  N
# 25469            Northeast        273772.47         Year                  N
# 25476            Northeast        279174.79         Year                  Y
#
#       case_status
# 14      Certified
# 34      Certified
# 130     Certified
# 216     Certified
# 221     Certified
# ...           ...
# 25191      Denied
# 25195   Certified
# 25468   Certified
# 25469   Certified
# 25476   Certified
#
# [427 rows x 12 columns]

# %%
outliers=outliers_df['prevailing_wage'].values.tolist()
l=[]
wage_data=visa_df['prevailing_wage']
wage_med=wage_data.median()
for value in wage_data:
    if value in outliers:
        l.append(wage_med)
    else:
        l.append(value)
visa_df['prevailing_wage1']=l
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status  prevailing_wage1
# 0          Denied          592.2029
# 1       Certified        83425.6500
# 2          Denied       122996.8600
# 3          Denied        83434.0300
# 4       Certified       149907.3900
# ...           ...               ...
# 25475   Certified        77092.5700
# 25476   Certified        70308.2100
# 25477   Certified       146298.8500
# 25478   Certified        86154.7700
# 25479   Certified        70876.9100
#
# [25480 rows x 13 columns]
